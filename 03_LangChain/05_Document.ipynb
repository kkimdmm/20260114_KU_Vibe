# %% [markdown]
# ## Document 객체와 속성
# LangChain의 `Document` 객체는 텍스트 데이터를 표현하는 기본 단위입니다.
#
# ### 주요 속성
# - page_content : 문서의 실제 텍스트 내용을 저장합니다
# - metadata : 문서와 관련된 메타데이터를 딕셔너리 형태로 저장합니다
#   - source : 문서의 출처 (파일 경로 등)
#   - page : 페이지 번호
#   - created_at : 생성 시간
#   - author : 작성자
#   등 사용자가 필요한 메타데이터를 자유롭게 추가 가능합니다

# %%
# %pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-1.2.6-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core<2.0.0,>=1.2.7 (from langchain)
#   Downloading langchain_core-1.2.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain)
#   Downloading langgraph-1.0.6-py3-none-any.whl.metadata (7.4 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.7->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.7->langchain)
#   Downloading langsmith-0.6.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\programdata\miniforge3\envs\sen\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\programdata\miniforge3\envs\sen\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programdata\miniforge3\envs\sen\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\programdata\miniforge3\envs\sen\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.7->langchain)
#   Downloading uuid_utils-0.13.0-cp39-abi3-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\miniforge3\envs\sen\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain) (3.0.0)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_checkpoint-4.0.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_prebuilt-1.0.6-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_sdk-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\programdata\miniforge3\envs\sen\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading orjson-3.11.5-cp312-cp312-win_amd64.whl.metadata (42 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\programdata\miniforge3\envs\sen\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain)
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in c:\programdata\miniforge3\envs\sen\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.12.1)
# Requirement already satisfied: certifi in c:\programdata\miniforge3\envs\sen\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\programdata\miniforge3\envs\sen\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\programdata\miniforge3\envs\sen\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\programdata\miniforge3\envs\sen\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\miniforge3\envs\sen\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\miniforge3\envs\sen\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.6.3)
# Downloading langchain-1.2.6-py3-none-any.whl (108 kB)
# Downloading langchain_core-1.2.7-py3-none-any.whl (490 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.0.6-py3-none-any.whl (157 kB)
# Downloading langgraph_checkpoint-4.0.0-py3-none-any.whl (46 kB)
# Downloading langgraph_prebuilt-1.0.6-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.3-py3-none-any.whl (67 kB)
# Downloading langsmith-0.6.4-py3-none-any.whl (283 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 14.1 MB/s  0:00:00
# Downloading uuid_utils-0.13.0-cp39-abi3-win_amd64.whl (183 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading orjson-3.11.5-cp312-cp312-win_amd64.whl (133 kB)
# Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl (117 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, typing-inspection, pydantic-core, ormsgpack, orjson, jsonpatch, annotated-types, requests-toolbelt, pydantic, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    ---------------------- ----------------- 10/18 [pydantic]
#    ---------------------- ----------------- 10/18 [pydantic]
#    ------------------------ --------------- 11/18 [langsmith]
#    ---------------------------- ----------- 13/18 [langchain-core]
#    ---------------------------- ----------- 13/18 [langchain-core]
#    ----------------------------------- ---- 16/18 [langgraph]
#    ------------------------------------- -- 17/18 [langchain]
#    ---------------------------------------- 18/18 [langchain]
#
# Successfully installed annotated-types-0.7.0 jsonpatch-1.33 langchain-1.2.6 langchain-core-1.2.7 langgraph-1.0.6 langgraph-checkpoint-4.0.0 langgraph-prebuilt-1.0.6 langgraph-sdk-0.3.3 langsmith-0.6.4 orjson-3.11.5 ormsgpack-1.12.2 pydantic-2.12.5 pydantic-core-2.41.5 requests-toolbelt-1.0.0 typing-inspection-0.4.2 uuid-utils-0.13.0 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.documents import Document

# 기본적인 Document 객체 생성
doc = Document(
    page_content="이것은 문서의 내용입니다.",
    metadata={
        "source": "example.txt", # 문서의 출처 (지금은 임의로 입력)
        "page": 1, # 페이지 번호
        "author": "홍길동", # 작성자
        "created_at": "2025-01-01" # 생성 시간
    }
)

# Document 객체의 속성 확인
print(doc.__dict__)
# Out:
# {'id': None, 'metadata': {'source': 'example.txt', 'page': 1, 'author': '홍길동', 'created_at': '2025-01-01'}, 'page_content': '이것은 문서의 내용입니다.', 'type': 'Document'}
